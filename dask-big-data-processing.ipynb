# %% [markdown]
# ## Big Data Processing using Distributed Dask on Fargate
#
# This notebook will demonstrate how to perform big data processing with Distributed Dask on Fargate  It will leverage Newyork taxi trips datasets for demonstrating how to process hundreds of millions of records to calculate total number of trips made each day, calculate mean of passengers  across trips for each day and max trip duration across trips etc

# %% [markdown]
# ## Setup conda packages dependencies
#
# Install cloudpickle version 1.6.0 to match the version used in dask package

# %%
# !conda install cloudpickle=1.6.0 -c conda-forge  -y

# %% [markdown]
# ## Connect to Dask Fargate Cluster.  You need to provision this cluster following the instructions from here https://github.com/rvvittal/aws-dask-sm-fargate

# %%
from dask.distributed import Client

#enable this client for local device testing
#client = Client()

#enable this client for local distributed cluster testing 
#client = Client('localhost:8786')

#enable this client for fargate distributed cluster testing
client = Client('Dask-Scheduler.local-dask:8786')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/distributed/client.py:1079: VersionMismatchWarning: Mismatched versions found
#
# cloudpickle
# +-----------------------+---------+
# |                       | version |
# +-----------------------+---------+
# | client                | 1.3.0   |
# | scheduler             | 1.6.0   |
# | tcp://11.0.3.179:9000 | 1.6.0   |
# | tcp://11.0.3.43:9000  | 1.6.0   |
# +-----------------------+---------+
#
# numpy
# +-----------------------+---------+
# |                       | version |
# +-----------------------+---------+
# | client                | 1.18.1  |
# | scheduler             | 1.19.1  |
# | tcp://11.0.3.179:9000 | 1.19.1  |
# | tcp://11.0.3.43:9000  | 1.19.1  |
# +-----------------------+---------+
#
# toolz
# +-----------------------+---------+
# |                       | version |
# +-----------------------+---------+
# | client                | 0.10.0  |
# | scheduler             | 0.11.1  |
# | tcp://11.0.3.179:9000 | 0.11.1  |
# | tcp://11.0.3.43:9000  | 0.11.1  |
# +-----------------------+---------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))

# %% [markdown]
# ## Scale out the number of dask workers as needed for your data science work

# %%
#enable this  when cluster is running on Fargate to scale out your cluster. 
# !sudo aws ecs update-service --service Dask-Workers --desired-count 4 --cluster Fargate-Dask-Cluster
# Out:
# {
#     "service": {
#         "serviceArn": "arn:aws:ecs:us-west-2:716664005094:service/Dask-Workers",
#         "serviceName": "Dask-Workers",
#         "clusterArn": "arn:aws:ecs:us-west-2:716664005094:cluster/Fargate-Dask-Cluster",
#         "loadBalancers": [],
#         "serviceRegistries": [
#             {
#                 "registryArn": "arn:aws:servicediscovery:us-west-2:716664005094:service/srv-ms5sjkuwukl7t6yq"
#             }
#         ],
#         "status": "ACTIVE",
#         "desiredCount": 4,
#         "runningCount": 2,
#         "pendingCount": 0,
#         "launchType": "FARGATE",
#         "platformVersion": "LATEST",
#         "taskDefinition": "arn:aws:ecs:us-west-2:716664005094:task-definition/cloudformation-dask-workers-v4:1",
#         "deploymentConfiguration": {
#             "maximumPercent": 200,
#             "minimumHealthyPercent": 100
#         },
#         "deployments": [
#             {
#                 "id": "ecs-svc/7695731697923122642",
#                 "status": "PRIMARY",
#                 "taskDefinition": "arn:aws:ecs:us-west-2:716664005094:task-definition/cloudformation-dask-workers-v4:1",
#                 "desiredCount": 4,
#                 "pendingCount": 0,
#                 "runningCount": 2,
#                 "createdAt": 1601235747.914,
#                 "updatedAt": 1601235883.701,
#                 "launchType": "FARGATE",
#                 "platformVersion": "1.3.0",
#                 "networkConfiguration": {
#                     "awsvpcConfiguration": {
#                         "subnets": [
#                             "subnet-07e8da2fc101abe8e"
#                         ],
#                         "securityGroups": [
#                             "sg-0911ccf97fd1bf9c1"
#                         ],
#                         "assignPublicIp": "ENABLED"
#                     }
#                 }
#             }
#         ],
#         "roleArn": "arn:aws:iam::716664005094:role/aws-service-role/ecs.amazonaws.com/AWSServiceRoleForECS",
#         "events": [
#             {
#                 "id": "655ddcf2-c157-4257-81d2-33b024d56cb6",
#                 "createdAt": 1601257563.94,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "17b900ef-d07c-43cd-91ac-ae19e442d66e",
#                 "createdAt": 1601235957.165,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "4813705b-7703-44f4-ac68-52daae414f5a",
#                 "createdAt": 1601235915.012,
#                 "message": "(service Dask-Workers) has stopped 2 running tasks: (task 7e554d53-270c-4c46-bcba-30d54cd63cf8) (task 1b7202be-57cc-41c2-b518-c784851cd646)."
#             },
#             {
#                 "id": "9e1f2d0e-2aba-4e7a-abc5-aa210bea3b72",
#                 "createdAt": 1601235760.78,
#                 "message": "(service Dask-Workers) has started 2 tasks: (task 48e218ee-e8df-4576-9d39-2614325a9ac5) (task 29070462-a9bb-43bd-b61b-82b755d42de8)."
#             },
#             {
#                 "id": "2b389a67-29a1-4d34-b3ae-12fbee8ac315",
#                 "createdAt": 1601228498.792,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "9e27cd22-f3b8-4f93-bc1f-a2c3f4611fce",
#                 "createdAt": 1601206893.539,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "22516129-3302-4da7-a701-6ed622ac8038",
#                 "createdAt": 1601185272.407,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "21e08680-78f9-46f5-b6a1-3d9e5f6627b9",
#                 "createdAt": 1601185262.582,
#                 "message": "(service Dask-Workers) has stopped 3 running tasks: (task 4deff871-d86b-449b-b813-0b9c918f6049) (task b55abe8a-f41a-4a68-86da-e7ed2b202a95) (task 31e325d1-73ce-4ee5-99e5-2d3b1904f784)."
#             },
#             {
#                 "id": "88ef4bae-4e33-4565-b387-acd6ea788422",
#                 "createdAt": 1601185251.323,
#                 "message": "(service Dask-Workers) has stopped 5 running tasks: (task 480daeb0-b714-4b82-b25a-b032160a54ce) (task 0306ddb1-48ff-4531-bba9-1a0aa9277d9b) (task d13e0467-6dd7-47b9-8211-455dbcccc279) (task fefc6400-e8c7-4a5e-838b-183fcdbdbb6c) (task 7c43efb3-c122-407a-aa80-a59d701af636)."
#             },
#             {
#                 "id": "372152a3-126a-4248-a502-3d58c73929ec",
#                 "createdAt": 1601174826.562,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "ff3af941-4b0e-48d1-9a5b-bbccfa9c514b",
#                 "createdAt": 1601174702.469,
#                 "message": "(service Dask-Workers) has started 3 tasks: (task 31e325d1-73ce-4ee5-99e5-2d3b1904f784) (task 7e554d53-270c-4c46-bcba-30d54cd63cf8) (task 4deff871-d86b-449b-b813-0b9c918f6049)."
#             },
#             {
#                 "id": "0c422c8c-eea7-4391-8548-3cb6198e0438",
#                 "createdAt": 1601174689.632,
#                 "message": "(service Dask-Workers) has started 5 tasks: (task 7c43efb3-c122-407a-aa80-a59d701af636) (task 0306ddb1-48ff-4531-bba9-1a0aa9277d9b) (task 1b7202be-57cc-41c2-b518-c784851cd646) (task fefc6400-e8c7-4a5e-838b-183fcdbdbb6c) (task d13e0467-6dd7-47b9-8211-455dbcccc279)."
#             },
#             {
#                 "id": "52de0546-0baa-4362-b995-84e2803e3152",
#                 "createdAt": 1601173302.504,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id":

#                 "message": "(service Dask-Workers) has started 1 tasks: (task e5d34086-5a14-4d65-bdc5-de4b20bbb8e3)."
#             }
#         ],
#         "createdAt": 1601158615.624,
#         "placementConstraints": [],
#         "placementStrategy": [],
#         "networkConfiguration": {
#             "awsvpcConfiguration": {
#                 "subnets": [
#                     "subnet-07e8da2fc101abe8e"
#                 ],
#                 "securityGroups": [
#                     "sg-0911ccf97fd1bf9c1"
#                 ],
#                 "assignPublicIp": "ENABLED"
#             }
#         },
#         "schedulingStrategy": "REPLICA",
#         "createdBy": "arn:aws:iam::716664005094:user/rvvittal",
#         "enableECSManagedTags": false,
#         "propagateTags": "NONE"
#     }
# }

# %% [markdown]
# ## Restart the client after scale out operation

# %%
client.restart()
# Out:
# <Client: 'tcp://11.0.3.142:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Introduction to Dask DataFrame
# A Dask DataFrame is a large parallel DataFrame composed of many smaller Pandas DataFrames, split along the index. These Pandas DataFrames may live on disk for larger-than-memory computing on a single machine, or on many different machines in a cluster. One Dask DataFrame operation triggers many operations on the constituent Pandas DataFrames. For more details, review this page: https://docs.dask.org/en/latest/dataframe.html

# %%
import s3fs
import dask.dataframe as dd
import boto3

# %% [markdown]
# ## Using Dask for EDA on NewYork Taxi Trip datasets

# %%
df = dd.read_csv(
    's3://nyc-tlc/trip data/yellow_tripdata_2018-*.csv', storage_options={'anon': True}, assume_missing=True, parse_dates=['tpep_pickup_datetime','tpep_dropoff_datetime']
)

# %% [markdown]
# ##  Calculate the trip duration in seconds

# %%
df['trip_dur_secs'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.seconds

# %%
# %%time
df.head()
# Out:
# CPU times: user 13.1 ms, sys: 0 ns, total: 13.1 ms
# Wall time: 5.59 s
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2018-01-01 00:21:05   2018-01-01 00:24:23              1.0
# 1       1.0  2018-01-01 00:44:55   2018-01-01 01:03:05              1.0
# 2       1.0  2018-01-01 00:08:26   2018-01-01 00:14:21              2.0
# 3       1.0  2018-01-01 00:20:22   2018-01-01 00:52:51              1.0
# 4       1.0  2018-01-01 00:09:18   2018-01-01 00:27:06              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.5         1.0                  N          41.0          24.0
# 1            2.7         1.0                  N         239.0         140.0
# 2            0.8         1.0                  N         262.0         141.0
# 3           10.2         1.0                  N         140.0         257.0
# 4            2.5         1.0                  N         246.0         239.0
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           2.0          4.5    0.5      0.5        0.00           0.0
# 1           2.0         14.0    0.5      0.5        0.00           0.0
# 2           1.0          6.0    0.5      0.5        1.00           0.0
# 3           2.0         33.5    0.5      0.5        0.00           0.0
# 4           1.0         12.5    0.5      0.5        2.75           0.0
#
#    improvement_surcharge  total_amount  trip_dur_secs
# 0                    0.3          5.80            198
# 1                    0.3         15.30           1090
# 2                    0.3          8.30            355
# 3                    0.3         34.80           1949
# 4                    0.3         16.55           1068

# %%
df.dtypes
# Out:
# VendorID                        float64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                    float64
# DOLocationID                    float64
# payment_type                    float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# trip_dur_secs                     int64
# dtype: object

# %% [markdown]
# ## Calculate max trip duration across all trips

# %%
# %%time
max_trip_duration = df.trip_dur_secs.max().compute()
print(max_trip_duration)
# Out:
# 86399
# CPU times: user 635 ms, sys: 1.25 ms, total: 637 ms
# Wall time: 1min 5s

# %% [markdown]
# ## Calculate total mean  of passengers across trips  by pickup date

# %%
# df['date_only'] = df['date_time_column'].dt.date
df['pickup_date'] = df['tpep_dropoff_datetime'].dt.date

# %%
# %%time
df.head()
# Out:
# CPU times: user 13.7 ms, sys: 0 ns, total: 13.7 ms
# Wall time: 4.8 s
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2018-01-01 00:21:05   2018-01-01 00:24:23              1.0
# 1       1.0  2018-01-01 00:44:55   2018-01-01 01:03:05              1.0
# 2       1.0  2018-01-01 00:08:26   2018-01-01 00:14:21              2.0
# 3       1.0  2018-01-01 00:20:22   2018-01-01 00:52:51              1.0
# 4       1.0  2018-01-01 00:09:18   2018-01-01 00:27:06              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.5         1.0                  N          41.0          24.0
# 1            2.7         1.0                  N         239.0         140.0
# 2            0.8         1.0                  N         262.0         141.0
# 3           10.2         1.0                  N         140.0         257.0
# 4            2.5         1.0                  N         246.0         239.0
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           2.0          4.5    0.5      0.5        0.00           0.0
# 1           2.0         14.0    0.5      0.5        0.00           0.0
# 2           1.0          6.0    0.5      0.5        1.00           0.0
# 3           2.0         33.5    0.5      0.5        0.00           0.0
# 4           1.0         12.5    0.5      0.5        2.75           0.0
#
#    improvement_surcharge  total_amount  trip_dur_secs pickup_date
# 0                    0.3          5.80            198  2018-01-01
# 1                    0.3         15.30           1090  2018-01-01
# 2                    0.3          8.30            355  2018-01-01
# 3                    0.3         34.80           1949  2018-01-01
# 4                    0.3         16.55           1068  2018-01-01

# %%
# %%time
df_mean_psngr_pickup_date = df.groupby('pickup_date').passenger_count.mean().compute()
# Out:
# CPU times: user 686 ms, sys: 9.58 ms, total: 695 ms
# Wall time: 1min 51s

# %% [markdown]
# ## Calculate total trips by pickup date

# %%
# %%time
df_trips_by_pickup_date = df.groupby('pickup_date').store_and_fwd_flag.count().compute()
# Out:
# CPU times: user 667 ms, sys: 8.55 ms, total: 675 ms
# Wall time: 1min 14s

# %%
len(df_trips_by_pickup_date)
# Out:
# 455

# %%
df_trips_by_pickup_date.head()
# Out:
# pickup_date
# 2002-12-31     10
# 2003-01-01     19
# 2008-12-31    278
# 2009-01-01    516
# 2017-01-02      1
# Name: store_and_fwd_flag, dtype: int64

# %%
# load and count number of rows
len(df)
# Out:
# 102804250

# %% [markdown]
# ## Find trips that had trip duration < 250 seconds

# %%
df_short = df[df.trip_dur_secs < 250]

# %%
df_short.head()
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0        1.0  2018-01-01 00:21:05   2018-01-01 00:24:23              1.0
# 5        1.0  2018-01-01 00:29:29   2018-01-01 00:32:48              3.0
# 7        1.0  2018-01-01 00:49:29   2018-01-01 00:51:53              1.0
# 27       2.0  2018-01-01 00:48:40   2018-01-01 00:51:30              5.0
# 34       2.0  2018-01-01 00:25:52   2018-01-01 00:29:24              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.50         1.0                  N          41.0          24.0
# 5            0.50         1.0                  N         143.0         143.0
# 7            0.70         1.0                  N         239.0         238.0
# 27           0.57         1.0                  N         142.0         239.0
# 34           0.49         1.0                  N         238.0         238.0
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0            2.0          4.5    0.5      0.5        0.00           0.0
# 5            2.0          4.5    0.5      0.5        0.00           0.0
# 7            1.0          4.0    0.5      0.5        1.00           0.0
# 27           1.0          4.0    0.5      0.5        1.06           0.0
# 34           1.0          4.5    0.5      0.5        1.45           0.0
#
#     improvement_surcharge  total_amount  trip_dur_secs pickup_date
# 0                     0.3          5.80            198  2018-01-01
# 5                     0.3          5.80            199  2018-01-01
# 7                     0.3          6.30            144  2018-01-01
# 27                    0.3          6.36            170  2018-01-01
# 34                    0.3          7.25            212  2018-01-01

# %%
len(df_short)
# Out:
# 11001092

# %% [markdown]
# ## Scale down Fargate resources when no longer needed

# %%
# !sudo aws ecs update-service --service Dask-Workers --desired-count 1 --cluster Fargate-Dask-Cluster
# Out:
# {
#     "service": {
#         "serviceArn": "arn:aws:ecs:us-west-2:716664005094:service/Dask-Workers",
#         "serviceName": "Dask-Workers",
#         "clusterArn": "arn:aws:ecs:us-west-2:716664005094:cluster/Fargate-Dask-Cluster",
#         "loadBalancers": [],
#         "serviceRegistries": [
#             {
#                 "registryArn": "arn:aws:servicediscovery:us-west-2:716664005094:service/srv-ms5sjkuwukl7t6yq"
#             }
#         ],
#         "status": "ACTIVE",
#         "desiredCount": 1,
#         "runningCount": 4,
#         "pendingCount": 0,
#         "launchType": "FARGATE",
#         "platformVersion": "LATEST",
#         "taskDefinition": "arn:aws:ecs:us-west-2:716664005094:task-definition/cloudformation-dask-workers-v4:1",
#         "deploymentConfiguration": {
#             "maximumPercent": 200,
#             "minimumHealthyPercent": 100
#         },
#         "deployments": [
#             {
#                 "id": "ecs-svc/7695731697923122642",
#                 "status": "PRIMARY",
#                 "taskDefinition": "arn:aws:ecs:us-west-2:716664005094:task-definition/cloudformation-dask-workers-v4:1",
#                 "desiredCount": 1,
#                 "pendingCount": 0,
#                 "runningCount": 4,
#                 "createdAt": 1601235747.914,
#                 "updatedAt": 1601263251.573,
#                 "launchType": "FARGATE",
#                 "platformVersion": "1.3.0",
#                 "networkConfiguration": {
#                     "awsvpcConfiguration": {
#                         "subnets": [
#                             "subnet-07e8da2fc101abe8e"
#                         ],
#                         "securityGroups": [
#                             "sg-0911ccf97fd1bf9c1"
#                         ],
#                         "assignPublicIp": "ENABLED"
#                     }
#                 }
#             }
#         ],
#         "roleArn": "arn:aws:iam::716664005094:role/aws-service-role/ecs.amazonaws.com/AWSServiceRoleForECS",
#         "events": [
#             {
#                 "id": "4eb608de-4f41-4929-a7d7-55910dee4179",
#                 "createdAt": 1601263251.577,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "adb376a1-d127-4b80-a1a7-e381c2ae2ad3",
#                 "createdAt": 1601263114.406,
#                 "message": "(service Dask-Workers) has started 2 tasks: (task 4b55f1f5-974a-4c0e-9914-dfe0637043af) (task b56d45df-b9cd-4709-bb74-d2f8bd0dfa8e)."
#             },
#             {
#                 "id": "655ddcf2-c157-4257-81d2-33b024d56cb6",
#                 "createdAt": 1601257563.94,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "17b900ef-d07c-43cd-91ac-ae19e442d66e",
#                 "createdAt": 1601235957.165,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "4813705b-7703-44f4-ac68-52daae414f5a",
#                 "createdAt": 1601235915.012,
#                 "message": "(service Dask-Workers) has stopped 2 running tasks: (task 7e554d53-270c-4c46-bcba-30d54cd63cf8) (task 1b7202be-57cc-41c2-b518-c784851cd646)."
#             },
#             {
#                 "id": "9e1f2d0e-2aba-4e7a-abc5-aa210bea3b72",
#                 "createdAt": 1601235760.78,
#                 "message": "(service Dask-Workers) has started 2 tasks: (task

#                 "message": "(service Dask-Workers) has started 5 tasks: (task 8d7efacb-daab-414f-8314-b5363313f74b) (task 3b290b0a-bbe1-4649-b227-c5a26b9a853c) (task 123e88a4-d2ca-42a4-9e94-5742601c945c) (task d2b03cc0-3082-4596-ae41-4743fb808c83) (task 07691a93-93c7-4b80-a86b-9b15071c9ba3)."
#             },
#             {
#                 "id": "398e73ab-2f3c-4496-98f9-ac5c3ea2eaf8",
#                 "createdAt": 1601170267.145,
#                 "message": "(service Dask-Workers) has started 5 tasks: (task 1affb32a-241d-4888-95d6-48f66e422d42) (task 50fd29a6-b437-47f2-93d1-5177251ffcb9) (task 546a44d2-1f7a-4b9e-94ef-8a12abb4345a) (task d2a48417-2a89-4efc-ab3b-7a42fbf1a8d5) (task dd3e7308-1dcd-477e-a4e0-2a56bcd4cd3d)."
#             },
#             {
#                 "id": "e1e14753-9d4f-4332-beaf-4231c1e06b88",
#                 "createdAt": 1601170255.095,
#                 "message": "(service Dask-Workers) has started 5 tasks: (task d5db6efc-934d-497f-b119-5cd68ac99230) (task a154f1c0-b47f-41cb-b624-d294ae96cd83) (task 4509d0f2-e7cc-4034-b256-06a95c87044f) (task 774bd6ee-ad21-4065-8822-5d7ccf85b827) (task a7cb9b67-e95c-4bcc-929a-3bd76f2f243a)."
#             },
#             {
#                 "id": "a2ebda37-3ee5-4207-a746-143a444f3dcf",
#                 "createdAt": 1601167238.639,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "34632e18-b3d4-4f82-9194-805e460d2193",
#                 "createdAt": 1601167124.123,
#                 "message": "(service Dask-Workers) has started 4 tasks: (task 78b1b7f8-d8b1-4d34-a4be-e9a4315c1244) (task 8658d5c0-88be-4864-afde-90e69127b869) (task a9928e97-8e1f-4df7-96ce-7a526b322b78) (task f3fdc4d5-d00f-47a6-815b-88ff40410763)."
#             },
#             {
#                 "id": "dc191d8a-f588-40df-9d75-f406c7d3e932",
#                 "createdAt": 1601167116.848,
#                 "message": "(service Dask-Workers) has started 5 tasks: (task 66198c52-1073-42f3-8427-80e238543c6a) (task dd5c9000-ed99-4f21-bc51-f38380254c2a) (task 0a94b334-1c02-4feb-a81a-2840a4fb3f15) (task 576260f5-4df5-4f02-8269-63811ee6d76a) (task 25c00c5e-cf9a-4c0e-a426-bd982d764dcb)."
#             },
#             {
#                 "id": "804dd2b6-ce5b-4f6b-80b7-585be33a3b8e",
#                 "createdAt": 1601158737.647,
#                 "message": "(service Dask-Workers) has reached a steady state."
#             },
#             {
#                 "id": "87b7884d-e909-4464-98e2-13854b23aa82",
#                 "createdAt": 1601158622.637,
#                 "message": "(service Dask-Workers) has started 1 tasks: (task e5d34086-5a14-4d65-bdc5-de4b20bbb8e3)."
#             }
#         ],
#         "createdAt": 1601158615.624,
#         "placementConstraints": [],
#         "placementStrategy": [],
#         "networkConfiguration": {
#             "awsvpcConfiguration": {
#                 "subnets": [
#                     "subnet-07e8da2fc101abe8e"
#                 ],
#                 "securityGroups": [
#                     "sg-0911ccf97fd1bf9c1"
#                 ],
#                 "assignPublicIp": "ENABLED"
#             }
#         },
#         "schedulingStrategy": "REPLICA",
#         "createdBy": "arn:aws:iam::716664005094:user/rvvittal",
#         "enableECSManagedTags": false,
#         "propagateTags": "NONE"
#     }
# }
